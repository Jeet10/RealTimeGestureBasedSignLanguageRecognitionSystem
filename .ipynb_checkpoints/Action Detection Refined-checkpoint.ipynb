# %% [markdown]
# # 1. Import and Install Dependencies

# %%
# !pip install tensorflow==2.4.1 tensorflow-gpu==2.4.1 opencv-python mediapipe sklearn matplotlib

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp

# %% [markdown]
# # 2. Keypoints using MP Holistic

# %%
mp_holistic = mp.solutions.holistic # Holistic model
mp_drawing = mp.solutions.drawing_utils # Drawing utilities

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
cap = cv2.VideoCapture(0)
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
    
        #Read Feed
        ret, frame = cap.read()
    
        #Make Detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)

        #Draw landmarks
        draw_styled_landmarks(image, results)
        
        #Show to Screen
        cv2.imshow('OpenCV Feed', image)
    
        #Break
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
draw_landmarks(frame, results)

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # 3. Extract Keypoint Values

# %%
# len(results.left_hand_landmarks.landmark)

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.49631372,  0.52958894, -0.65800822, ...,  0.17710263,
#         0.29576859, -0.05362605])

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.49631372,  0.52958894, -0.65800822, ...,  0.17710263,
#         0.29576859, -0.05362605])

# %% [markdown]
# # 4. Setup Folders for Collection

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
# actions = np.array(['hello', 'thanks', 'iloveyou', 'i', 'father', 'mother', 'yes', 'no', 'help', 'what'])
# actions = np.array(['hello', 'thanks','iloveyou','i'])
actions = np.array(['hello', 'iloveyou', 'thanks','i', 'yes'])

# Thirty videos worth of data
no_sequences = 30

# Videos are going to be 30 frames in length
sequence_length = 30

# Folder start
start_folder = 30

# %%
for action in actions: 
    # dirmax = np.max(np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int))
    for sequence in range(no_sequences):
        try: 
            os.makedirs(os.path.join(DATA_PATH, action, str(sequence)))
        except:
            pass

# %% [markdown]
# # 5. Collect Keypoint Values for Training and Testing

# %%
cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    
    # NEW LOOP
    # Loop through actions
    for action in actions:
        if action == 'yes':

            # Loop through sequences aka videos
            for sequence in range(no_sequences):
                # Loop through video length aka sequence length
                for frame_num in range(sequence_length):
    
                    # Read feed
                    ret, frame = cap.read()
    
                    # Make detections
                    image, results = mediapipe_detection(frame, holistic)
    
                    # Draw landmarks
                    draw_styled_landmarks(image, results)
                    
                    # NEW Apply wait logic
                    if frame_num == 0: 
                        cv2.putText(image, 'STARTING COLLECTION', (120,200), 
                                   cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255, 0), 4, cv2.LINE_AA)
                        cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                        # Show to screen
                        cv2.imshow('OpenCV Feed', image)
                        cv2.waitKey(500)
                    else: 
                        cv2.putText(image, 'Collecting frames for {} Video Number {}'.format(action, sequence), (15,12), 
                                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                        # Show to screen
                        cv2.imshow('OpenCV Feed', image)
                    
                    # NEW Export keypoints
                    keypoints = extract_keypoints(results)
                    npy_path = os.path.join(DATA_PATH, action, str(sequence), str(frame_num))
                    np.save(npy_path, keypoints)
    
                    # Break gracefully
                    if cv2.waitKey(10) & 0xFF == ord('q'):
                        break
                        
    cap.release()
    cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 6. Preprocess Data and Create Labels and Features

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'iloveyou': 1, 'thanks': 2, 'i': 3, 'father': 4, 'mother': 5}

# %%
sequences, labels = [], []
for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):
            res = np.load(os.path.join(DATA_PATH, action, str(sequence), "{}.npy".format(frame_num)))
            window.append(res)
        sequences.append(window)
        labels.append(label_map[action])

# %%
np.array(sequences).shape
# Out:
# (180, 30, 1662)

# %%
np.array(labels).shape
# Out:
# (180,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (180, 30, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (9, 6)

# %% [markdown]
# # 7. Build and Train LSTM Neural Network

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
# Out:
# Epoch 1/2000
# 6/6 [==============================] - 3s 169ms/step - loss: 1.8008 - categorical_accuracy: 0.2186
# Epoch 2/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 1.7858 - categorical_accuracy: 0.1520
# Epoch 3/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.7965 - categorical_accuracy: 0.1529
# Epoch 4/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 1.8003 - categorical_accuracy: 0.1736
# Epoch 5/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.7907 - categorical_accuracy: 0.1906
# Epoch 6/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.7911 - categorical_accuracy: 0.1877
# Epoch 7/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.7644 - categorical_accuracy: 0.3810
# Epoch 8/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.6777 - categorical_accuracy: 0.5510
# Epoch 9/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 1.5547 - categorical_accuracy: 0.5250
# Epoch 10/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3516 - categorical_accuracy: 0.5643
# Epoch 11/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.2553 - categorical_accuracy: 0.4752
# Epoch 12/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.0843 - categorical_accuracy: 0.5136
# Epoch 13/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 0.9299 - categorical_accuracy: 0.4886
# Epoch 14/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.0533 - categorical_accuracy: 0.5131
# Epoch 15/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 1.4732 - categorical_accuracy: 0.3210
# Epoch 16/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 1.4171 - categorical_accuracy: 0.3287
# Epoch 17/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.3592 - categorical_accuracy: 0.3245
# Epoch 18/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 1.1961 - categorical_accuracy: 0.5056
# Epoch 19/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.0528 - categorical_accuracy: 0.5179
# Epoch 20/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 0.9911 - categorical_accuracy: 0.4434
# Epoch 21/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 0.8732 - categorical_accuracy: 0.4952
# Epoch 22/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 0.9093 - categorical_accuracy: 0.5499
# Epoch 23/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.9599 - categorical_accuracy: 0.4333
# Epoch 24/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.5947 - categorical_accuracy: 0.2701
# Epoch 25/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.6062 - categorical_accuracy: 0.3275
# Epoch 26/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.5588 - categorical_accuracy: 0.2805
# Epoch 27/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.4720 - categorical_accuracy: 0.4474
# Epoch 28/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.4604 - categorical_accuracy: 0.3145
# Epoch 29/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.8869 - categorical_accuracy: 0.1606
# Epoch 30/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.7384 - categorical_accuracy: 0.1603
# Epoch 31/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.6247 - categorical_accuracy: 0.3164
# Epoch 32/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 1.5559 - categorical_accuracy: 0.3248
# Epoch 33/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.4497 - categorical_accuracy: 0.3437
# Epoch 34/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.4186 - categorical_accuracy: 0.3734
# Epoch 35/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 1.3393 - categorical_accuracy: 0.3330
# Epoch 36/2000
# 6/6 [==============================] - 1s 95ms/step - loss: 1.3717 - categorical_accuracy: 0.3337
# Epoch 37/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.3769 - categorical_accuracy: 0.3041
# Epoch 38/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.3623 - categorical_accuracy: 0.3223
# Epoch 39/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.3297 - categorical_accuracy: 0.3406
# Epoch 40/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 1.3473 - categorical_accuracy: 0.3250
# Epoch 41/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.2962 - categorical_accuracy: 0.3533
# Epoch 42/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.3505 - categorical_accuracy: 0.3671
# Epoch 43/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.3238 - categorical_accuracy: 0.3782
# Epoch 44/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.3155 - categorical_accuracy: 0.4257
# Epoch 45/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.3266 - categorical_accuracy: 0.3538
# Epoch 46/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.3440 - categorical_accuracy: 0.3976
# Epoch 47/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.3255 - categorical_accuracy: 0.3500
# Epoch 48/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.3747 - categorical_accuracy: 0.3462
# Epoch 49/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.3900 - categorical_accuracy: 0.2622
# Epoch 50/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.3518 - categorical_accuracy: 0.3500
# Epoch 51/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.3390 - categorical_accuracy: 0.3334
# Epoch 52/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.3288 - categorical_accuracy: 0.3650
# Epoch 53/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 1.3488 - categorical_accuracy: 0.3261
# Epoch 54/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.2899 - categorical_accuracy: 0.3881
# Epoch 55/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.3159 - categorical_accuracy: 0.5203
# Epoch 56/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3646 - categorical_accuracy: 0.3343
# Epoch 57/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.3024 - categorical_accuracy: 0.4082
# Epoch 58/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 1.3343 - categorical_accuracy: 0.3660
# Epoch 59/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.3035 - categorical_accuracy: 0.3736
# Epoch 60/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.3583 - categorical_accuracy: 0.3305
# Epoch 61/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.2972 - categorical_accuracy: 0.3765
# Epoch 62/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.2778 - categorical_accuracy: 0.4138
# Epoch 63/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.2861 - categorical_accuracy: 0.3843
# Epoch 64/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.2519 - categorical_accuracy: 0.5155
# Epoch 65/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.1710 - categorical_accuracy: 0.5039
# Epoch 66/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 1.1302 - categorical_accuracy: 0.4977
# Epoch 67/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.1074 - categorical_accuracy: 0.5056
# Epoch 68/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.2353 - categorical_accuracy: 0.4955
# Epoch 69/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 0.9947 - categorical_accuracy: 0.5169
# Epoch 70/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 0.8784 - categorical_accuracy: 0.5287
# Epoch 71/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 0.8482 - categorical_accuracy: 0.5254
# Epoch 72/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 0.8871 - categorical_accuracy: 0.5473
# Epoch 73/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 0.9166 - categorical_accuracy: 0.4598
# Epoch 74/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 0.8456 - categorical_accuracy: 0.4988
# Epoch 75/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 0.8162 - categorical_accuracy: 0.4926
# Epoch 76/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 0.7811 - categorical_accuracy: 0.5452
# Epoch 77/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 0.7852 - categorical_accuracy: 0.5607
# Epoch 78/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 0.7740 - categorical_accuracy: 0.5390
# Epoch 79/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 0.7902 - categorical_accuracy: 0.5016
# Epoch 80/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 0.8172 - categorical_accuracy: 0.4884
# Epoch 81/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 1.1405 - categorical_accuracy: 0.4647
# Epoch 82/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.7039 - categorical_accuracy: 0.4139
# Epoch 83/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.3791 - categorical_accuracy: 0.3829
# Epoch 84/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.1232 - categorical_accuracy: 0.5618
# Epoch 85/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.1617 - categorical_accuracy: 0.4787
# Epoch 86/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 0.9560 - categorical_accuracy: 0.5188
# Epoch 87/2000
# 6/6 [==============================] - 1s 95ms/step - loss: 0.9133 - categorical_accuracy: 0.4913
# Epoch 88/2000
# 6/6 [==============================] - 1s 95ms/step - loss: 0.8036 - categorical_accuracy: 0.6922
# Epoch 89/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 0.8125 - categorical_accuracy: 0.6550
# Epoch 90/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 0.7835 - categorical_accuracy: 0.6385
# Epoch 91/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 0.7090 - categorical_accuracy: 0.6654
# Epoch 92/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 0.6850 - categorical_accuracy: 0.6792
# Epoch 93/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 0.5948 - categorical_accuracy: 0.7134
# Epoch 94/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 0.5927 - categorical_accuracy: 0.6785
# Epoch 95/2000
# 6/6 [==============================] - 1s 96ms/step - loss: 0.5749 - categorical_accuracy: 0.7061
# Epoch 96/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 0.6153 - categorical_accuracy: 0.6783
# Epoch 97/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 0.5268 - categorical_accuracy: 0.7265
# Epoch 98/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 0.5261 - categorical_accuracy: 0.7211
# Epoch 99/2000
# 6/6 [==============================] - 1s 99ms/step - loss: 0.5829 - categorical_accuracy: 0.6291
# Epoch 100/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 0.5271 - categorical_accuracy: 0.6626
# Epoch 101/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 0.5631 - categorical_accuracy: 0.7186
# Epoch 102/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 0.5718 - categorical_accuracy: 0.6263
# Epoch 103/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 0.5453 - categorical_accuracy: 0.6828
# Epoch 104/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 0.5677 - categorical_accuracy: 0.6817
# Epoch 105/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 0.5842 - categorical_accuracy: 0.6626
# Epoch 106/2000
# 6/6 [==============================] - 1s 87ms/step - loss: 0.5387 - categorical_accuracy: 0.6748
# Epoch 107/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 0.5139 - categorical_accuracy: 0.6484
# Epoch 108/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 0.5477 - categorical_accuracy: 0.6763
# Epoch 109/2000
# 6/6 [==============================] - 1s 96ms/step - loss: 0.5559 - categorical_accuracy: 0.6797
# Epoch 110/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 0.5156 - categorical_accuracy: 0.7050
# Epoch 111/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 0.5865 - categorical_accuracy: 0.6611
# Epoch 112/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 0.5591 - categorical_accuracy: 0.6449
# Epoch 113/2000
# 6/6 [==============================] - 1s 96ms/step - loss: 0.5557 - categorical_accuracy: 0.6788
# Epoch 114/2000
# 6/6 [==============================] - 1s 96ms/step - loss: 0.5575 - categorical_accuracy: 0.6622
# Epoch 115/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 0.5319 - categorical_accuracy: 0.6548
# Epoch 116/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 0.5697 - categorical_accuracy: 0.6773
# Epoch 117/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 0.5259 - categorical_accuracy: 0.6707
# Epoch 118/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 0.5222 - categorical_accuracy: 0.6863
# Epoch 119/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 0.5391 - categorical_accuracy: 0.6648
# Epoch 120/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 0.5101 - categorical_accuracy: 0.7029
# Epoch 121/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 0.5258 - categorical_accuracy: 0.7128
# Epoch 122/2000
# 6/6 [==============================] - 1s 87ms/step - loss: 0.5471 - categorical_accuracy: 0.6535
# Epoch 123/2000
# 6/6 [==============================] - 1s 87ms/step - loss: 0.5693 - categorical_accuracy: 0.6466
# Epoch 124/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 0.5497 - categorical_accuracy: 0.6858
# Epoch 125/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 0.5347 - categorical_accuracy: 0.6808
# Epoch 126/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 0.5310 - categorical_accuracy: 0.6570
# Epoch 127/2000
# 6/6 [==============================] - 1s 87ms/step - loss: 0.5590 - categorical_accuracy: 0.6414
# Epoch 128/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 0.5857 - categorical_accuracy: 0.6463
# Epoch 129/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 0.5653 - categorical_accuracy: 0.6732
# Epoch 130/2000
# 6/6 [==============================] - 1s 96ms/step - loss: 0.5568 - categorical_accuracy: 0.6869
# Epoch 131/2000
# 6/6 [==============================] - 1s 96ms/step - loss: 0.5745 - categorical_accuracy: 0.6471
# Epoch 132/2000
# 6/6 [==============================] - 1s 98ms/step - loss: 0.5656 - categorical_accuracy: 0.6386
# Epoch 133/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 0.5326 - categorical_accuracy: 0.6736
# Epoch 134/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 0.5766 - categorical_accuracy: 0.6199
# Epoch 135/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 0.5496 - categorical_accuracy: 0.6884
# Epoch 136/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 0.5388 - categorical_accuracy: 0.6718
# Epoch 137/2000
# 6/6 [==============================] - 1s 87ms/step - loss: 0.5362 - categorical_accuracy: 0.7296
# Epoch 138/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 0.5333 - categorical_accuracy: 0.7016
# Epoch 139/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 1.7332 - categorical_accuracy: 0.5006
# Epoch 140/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 2.3954 - categorical_accuracy: 0.2089
# Epoch 141/2000
# 6/6 [==============================] - 1s 97ms/step - loss: 1.6221 - categorical_accuracy: 0.3055
# Epoch 142/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.3866 - categorical_accuracy: 0.3115
# Epoch 143/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.3208 - categorical_accuracy: 0.3402
# Epoch 144/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3582 - categorical_accuracy: 0.3052
# Epoch 145/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.3664 - categorical_accuracy: 0.3287
# Epoch 146/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.3164 - categorical_accuracy: 0.3632
# Epoch 147/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.3028 - categorical_accuracy: 0.3654
# Epoch 148/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.3563 - categorical_accuracy: 0.3571
# Epoch 149/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.3202 - categorical_accuracy: 0.3631
# Epoch 150/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3367 - categorical_accuracy: 0.3177
# Epoch 151/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.3126 - categorical_accuracy: 0.3437
# Epoch 152/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 1.2078 - categorical_accuracy: 0.4069
# Epoch 153/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.1592 - categorical_accuracy: 0.5225
# Epoch 154/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.0540 - categorical_accuracy: 0.4780
# Epoch 155/2000
# 6/6 [==============================] - 1s 96ms/step - loss: 0.9342 - categorical_accuracy: 0.4827
# Epoch 156/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 0.8549 - categorical_accuracy: 0.4879
# Epoch 157/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 0.8607 - categorical_accuracy: 0.4879
# Epoch 158/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 0.8171 - categorical_accuracy: 0.4937
# Epoch 159/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 0.7722 - categorical_accuracy: 0.5159
# Epoch 160/2000
# 6/6 [==============================] - 1s 87ms/step - loss: 0.7854 - categorical_accuracy: 0.5088
# Epoch 161/2000
# 6/6 [==============================] - 1s 86ms/step - loss: 1.3347 - categorical_accuracy: 0.5220
# Epoch 162/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 2.2363 - categorical_accuracy: 0.3233
# Epoch 163/2000
# 6/6 [==============================] - 1s 87ms/step - loss: 1.4602 - categorical_accuracy: 0.3508
# Epoch 164/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.4324 - categorical_accuracy: 0.3472
# Epoch 165/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.3607 - categorical_accuracy: 0.3427
# Epoch 166/2000
# 6/6 [==============================] - 1s 87ms/step - loss: 1.3674 - categorical_accuracy: 0.3662
# Epoch 167/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 1.3287 - categorical_accuracy: 0.3571
# Epoch 168/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.3465 - categorical_accuracy: 0.3424
# Epoch 169/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 1.4022 - categorical_accuracy: 0.3105
# Epoch 170/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.3543 - categorical_accuracy: 0.3287
# Epoch 171/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.3243 - categorical_accuracy: 0.3408
# Epoch 172/2000
# 6/6 [==============================] - 1s 87ms/step - loss: 1.3682 - categorical_accuracy: 0.3357
# Epoch 173/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 1.3770 - categorical_accuracy: 0.3326
# Epoch 174/2000
# 6/6 [==============================] - 1s 87ms/step - loss: 1.3623 - categorical_accuracy: 0.2767
# Epoch 175/2000
# 6/6 [==============================] - 1s 87ms/step - loss: 1.3300 - categorical_accuracy: 0.3355
# Epoch 176/2000
# 6/6 [==============================] - 1s 87ms/step - loss: 1.3744 - categorical_accuracy: 0.2937
# Epoch 177/2000
# 6/6 [==============================] - 1s 86ms/step - loss: 1.3374 - categorical_accuracy: 0.3424
# Epoch 178/2000
# 6/6 [==============================] - 1s 95ms/step - loss: 1.3593 - categorical_accuracy: 0.3305
# Epoch 179/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.2853 - categorical_accuracy: 0.3547
# Epoch 180/2000
# 6/6 [==============================] - 1s 96ms/step - loss: 1.3308 - categorical_accuracy: 0.3305
# Epoch 181/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.3608 - categorical_accuracy: 0.3218
# Epoch 182/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.3571 - categorical_accuracy: 0.3254
# Epoch 183/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3862 - categorical_accuracy: 0.3196
# Epoch 184/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3327 - categorical_accuracy: 0.3382
# Epoch 185/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.2974 - categorical_accuracy: 0.3668
# Epoch 186/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.3254 - categorical_accuracy: 0.3338
# Epoch 187/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3500 - categorical_accuracy: 0.3485
# Epoch 188/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.3826 - categorical_accuracy: 0.3083
# Epoch 189/2000
# 6/6 [==============================] - 1s 96ms/step - loss: 1.3469 - categorical_accuracy: 0.3601
# Epoch 190/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 1.3177 - categorical_accuracy: 0.3456
# Epoch 191/2000
# 6/6 [==============================] - 1s 96ms/step - loss: 1.3212 - categorical_accuracy: 0.3535
# Epoch 192/2000
# 6/6 [==============================] - 1s 95ms/step - loss: 1.3589 - categorical_accuracy: 0.3195
# Epoch 193/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.3323 - categorical_accuracy: 0.3666
# Epoch 194/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3087 - categorical_accuracy: 0.3468
# Epoch 195/2000
# 6/6 [==============================] - 1s 96ms/step - loss: 1.3497 - categorical_accuracy: 0.3335
# Epoch 196/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.3059 - categorical_accuracy: 0.3674
# Epoch 197/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 1.3534 - categorical_accuracy: 0.3250
# Epoch 198/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.3105 - categorical_accuracy: 0.3294
# Epoch 199/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.3409 - categorical_accuracy: 0.3478
# Epoch 200/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.4219 - categorical_accuracy: 0.2993
# Epoch 201/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.3264 - categorical_accuracy: 0.3095
# Epoch 202/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3183 - categorical_accuracy: 0.3621
# Epoch 203/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.2925 - categorical_accuracy: 0.3419
# Epoch 204/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3107 - categorical_accuracy: 0.3551
# Epoch 205/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3875 - categorical_accuracy: 0.3002
# Epoch 206/2000
# 6/6 [==============================] - 1s 95ms/step - loss: 1.3260 - categorical_accuracy: 0.3330
# Epoch 207/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3627 - categorical_accuracy: 0.3346
# Epoch 208/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.2938 - categorical_accuracy: 0.3421
# Epoch 209/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 1.3517 - categorical_accuracy: 0.3102
# Epoch 210/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.3311 - categorical_accuracy: 0.3420
# Epoch 211/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3198 - categorical_accuracy: 0.3743
# Epoch 212/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.3695 - categorical_accuracy: 0.3202
# Epoch 213/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.3561 - categorical_accuracy: 0.3416
# Epoch 214/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.3100 - categorical_accuracy: 0.3468
# Epoch 215/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3285 - categorical_accuracy: 0.3882
# Epoch 216/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.2773 - categorical_accuracy: 0.4298
# Epoch 217/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.2952 - categorical_accuracy: 0.3680
# Epoch 218/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.2625 - categorical_accuracy: 0.4870
# Epoch 219/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.1764 - categorical_accuracy: 0.5067
# Epoch 220/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.1226 - categorical_accuracy: 0.4719
# Epoch 221/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.0824 - categorical_accuracy: 0.5345
# Epoch 222/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.0487 - categorical_accuracy: 0.4995
# Epoch 223/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 0.9647 - categorical_accuracy: 0.4873
# Epoch 224/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 0.9759 - categorical_accuracy: 0.4752
# Epoch 225/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.5485 - categorical_accuracy: 0.3118
# Epoch 226/2000
# 6/6 [==============================] - 1s 96ms/step - loss: 1.3510 - categorical_accuracy: 0.3545
# Epoch 227/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.3777 - categorical_accuracy: 0.3590
# Epoch 228/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.3370 - categorical_accuracy: 0.2915
# Epoch 229/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.2418 - categorical_accuracy: 0.5178
# Epoch 230/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.2345 - categorical_accuracy: 0.5041
# Epoch 231/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.0563 - categorical_accuracy: 0.4872
# Epoch 232/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 0.9127 - categorical_accuracy: 0.4943
# Epoch 233/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 0.8620 - categorical_accuracy: 0.5007
# Epoch 234/2000
# 6/6 [==============================] - 1s 95ms/step - loss: 0.8101 - categorical_accuracy: 0.5416
# Epoch 235/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 0.7983 - categorical_accuracy: 0.5395
# Epoch 236/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 0.8122 - categorical_accuracy: 0.4569
# Epoch 237/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 0.7884 - categorical_accuracy: 0.5093
# Epoch 238/2000
# 6/6 [==============================] - 1s 95ms/step - loss: 0.7995 - categorical_accuracy: 0.4805
# Epoch 239/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 0.7796 - categorical_accuracy: 0.5165
# Epoch 240/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 0.7830 - categorical_accuracy: 0.5000
# Epoch 241/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 0.7743 - categorical_accuracy: 0.5618
# Epoch 242/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 0.7962 - categorical_accuracy: 0.4823
# Epoch 243/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 0.8006 - categorical_accuracy: 0.4900
# Epoch 244/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 0.7970 - categorical_accuracy: 0.4826
# Epoch 245/2000
# 6/6 [==============================] - 1s 96ms/step - loss: 0.7772 - categorical_accuracy: 0.4633
# Epoch 246/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 0.7868 - categorical_accuracy: 0.4859
# Epoch 247/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 0.7591 - categorical_accuracy: 0.6009
# Epoch 248/2000
# 6/6 [==============================] - 1s 95ms/step - loss: 0.8025 - categorical_accuracy: 0.5213
# Epoch 249/2000
# 6/6 [==============================] - 1s 102ms/step - loss: 0.7832 - categorical_accuracy: 0.4582
# Epoch 250/2000
# 6/6 [==============================] - 1s 97ms/step - loss: 0.7984 - categorical_accuracy: 0.5128
# Epoch 251/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 0.7470 - categorical_accuracy: 0.5136
# Epoch 252/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 0.7404 - categorical_accuracy: 0.5277
# Epoch 253/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 0.7791 - categorical_accuracy: 0.5403
# Epoch 254/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 0.7888 - categorical_accuracy: 0.4788
# Epoch 255/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 0.7588 - categorical_accuracy: 0.6218
# Epoch 256/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 1.2629 - categorical_accuracy: 0.5421
# Epoch 257/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 2.0167 - categorical_accuracy: 0.4006
# Epoch 258/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 2.1686 - categorical_accuracy: 0.3219
# Epoch 259/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.5640 - categorical_accuracy: 0.3224
# Epoch 260/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.3961 - categorical_accuracy: 0.3603
# Epoch 261/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3965 - categorical_accuracy: 0.3200
# Epoch 262/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3817 - categorical_accuracy: 0.3302
# Epoch 263/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.3579 - categorical_accuracy: 0.3294
# Epoch 264/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.3485 - categorical_accuracy: 0.3115
# Epoch 265/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3956 - categorical_accuracy: 0.2833
# Epoch 266/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 1.3646 - categorical_accuracy: 0.3730
# Epoch 267/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.3693 - categorical_accuracy: 0.3378
# Epoch 268/2000
# 6/6 [==============================] - 1s 88ms/step - loss: 1.3915 - categorical_accuracy: 0.3328
# Epoch 269/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3412 - categorical_accuracy: 0.3334
# Epoch 270/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.3229 - categorical_accuracy: 0.3315
# Epoch 271/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3070 - categorical_accuracy: 0.3762
# Epoch 272/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3227 - categorical_accuracy: 0.3006
# Epoch 273/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3440 - categorical_accuracy: 0.3465
# Epoch 274/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3616 - categorical_accuracy: 0.3156
# Epoch 275/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3323 - categorical_accuracy: 0.3441
# Epoch 276/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.3615 - categorical_accuracy: 0.3256
# Epoch 277/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.3681 - categorical_accuracy: 0.3427
# Epoch 278/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.3610 - categorical_accuracy: 0.3236
# Epoch 279/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3586 - categorical_accuracy: 0.3110
# Epoch 280/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.3485 - categorical_accuracy: 0.3397
# Epoch 281/2000
# 6/6 [==============================] - 1s 89ms/step - loss: 1.3172 - categorical_accuracy: 0.3426
# Epoch 282/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3223 - categorical_accuracy: 0.3376
# Epoch 283/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.3495 - categorical_accuracy: 0.3165
# Epoch 284/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3522 - categorical_accuracy: 0.3329
# Epoch 285/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.3635 - categorical_accuracy: 0.3050
# Epoch 286/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.3494 - categorical_accuracy: 0.3065
# Epoch 287/2000
# 6/6 [==============================] - 1s 95ms/step - loss: 1.3347 - categorical_accuracy: 0.3938
# Epoch 288/2000
# 6/6 [==============================] - 1s 95ms/step - loss: 1.3448 - categorical_accuracy: 0.2772
# Epoch 289/2000
# 6/6 [==============================] - 1s 96ms/step - loss: 1.3354 - categorical_accuracy: 0.2918
# Epoch 290/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.3480 - categorical_accuracy: 0.3140
# Epoch 291/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.4857 - categorical_accuracy: 0.3455
# Epoch 292/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 2.3649 - categorical_accuracy: 0.2127
# Epoch 293/2000
# 6/6 [==============================] - 1s 99ms/step - loss: 2.1281 - categorical_accuracy: 0.1550
# Epoch 294/2000
# 6/6 [==============================] - 1s 97ms/step - loss: 1.8514 - categorical_accuracy: 0.1873
# Epoch 295/2000
# 6/6 [==============================] - 1s 95ms/step - loss: 1.8106 - categorical_accuracy: 0.1389
# Epoch 296/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.7914 - categorical_accuracy: 0.1834
# Epoch 297/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.7936 - categorical_accuracy: 0.1726
# Epoch 298/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.7937 - categorical_accuracy: 0.1577
# Epoch 299/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.7874 - categorical_accuracy: 0.2037
# Epoch 300/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.7888 - categorical_accuracy: 0.1727
# Epoch 301/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.7963 - categorical_accuracy: 0.1596
# Epoch 302/2000
# 6/6 [==============================] - 1s 91ms/step - loss: 1.7904 - categorical_accuracy: 0.1911
# Epoch 303/2000
# 6/6 [==============================] - 1s 96ms/step - loss: 1.7909 - categorical_accuracy: 0.1854
# Epoch 304/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.7914 - categorical_accuracy: 0.1595
# Epoch 305/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.7926 - categorical_accuracy: 0.1717
# Epoch 306/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 1.7913 - categorical_accuracy: 0.1575
# Epoch 307/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.7896 - categorical_accuracy: 0.1456
# Epoch 308/2000
# 6/6 [==============================] - 1s 90ms/step - loss: 1.7905 - categorical_accuracy: 0.1701
# Epoch 309/2000
# 6/6 [==============================] - 1s 94ms/step - loss: 1.7923 - categorical_accuracy: 0.1825
# Epoch 310/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.7925 - categorical_accuracy: 0.1250
# Epoch 311/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.7914 - categorical_accuracy: 0.2060
# Epoch 312/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.7936 - categorical_accuracy: 0.1750
# Epoch 313/2000
# 6/6 [==============================] - 1s 96ms/step - loss: 1.7910 - categorical_accuracy: 0.1725
# Epoch 314/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.7905 - categorical_accuracy: 0.1683
# Epoch 315/2000
# 6/6 [==============================] - 1s 93ms/step - loss: 1.7930 - categorical_accuracy: 0.1674
# Epoch 316/2000
# 6/6 [==============================] - 1s 96ms/step - loss: 1.7926 - categorical_accuracy: 0.1565
# Epoch 317/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.7894 - categorical_accuracy: 0.1698
# Epoch 318/2000
# 6/6 [==============================] - 1s 92ms/step - loss: 1.7901 - categorical_accuracy: 0.1843
# Epoch 319/2000
# 3/6 [==============>...............] - ETA: 0s - loss: 1.7913 - categorical_accuracy: 0.1615
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[186], line 1
# ----> 1 model.fit(X_train, y_train, epochs=2000, callbacks=[tb_callback])
#
# File c:\users\jeetd\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\keras\engine\training.py:1100, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1093 with trace.Trace(
#    1094     'train',
#    1095     epoch_num=epoch,
#    1096     step_num=step,
#    1097     batch_size=batch_size,
#    1098     _r=1):
#    1099   callbacks.on_train_batch_begin(step)
# -> 1100   tmp_logs = self.train_function(iterator)
#    1101   if data_handler.should_sync:
#    1102     context.async_wait()
#
# File c:\users\jeetd\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\def_function.py:828, in Function.__call__(self, *args, **kwds)
#     826 tracing_count = self.experimental_get_tracing_count()
#     827 with trace.Trace(self._name) as tm:
# --> 828   result = self._call(*args, **kwds)
#     829   compiler = "xla" if self._experimental_compile else "nonXla"
#     830   new_tracing_count = self.experimental_get_tracing_count()
#
# File c:\users\jeetd\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\def_function.py:855, in Function._call(self, *args, **kwds)
#     852   self._lock.release()
#     853   # In this case we have created variables on the first call, so we run the
#     854   # defunned version which is guaranteed to never create variables.
# --> 855   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856 elif self._stateful_fn is not None:
#     857   # Release the lock early so that multiple threads can perform the call
#     858   # in parallel.
#     859   self._lock.release()
#
# File c:\users\jeetd\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\function.py:2942, in Function.__call__(self, *args, **kwargs)
#    2939 with self._lock:
#    2940   (graph_function,
#    2941    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942 return graph_function._call_flat(
#    2943     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\users\jeetd\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\function.py:1918, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1914 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1915 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1916     and executing_eagerly):
#    1917   # No tape is watching; skip to running the function.
# -> 1918   return self._build_call_outputs(self._inference_function.call(
#    1919       ctx, args, cancellation_manager=cancellation_manager))
#    1920 forward_backward = self._select_forward_and_backward_functions(
#    1921     args,
#    1922     possible_gradient_type,
#    1923     executing_eagerly)
#    1924 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\users\jeetd\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\function.py:555, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     553 with _InterpolateFunctionError(self):
#     554   if cancellation_manager is None:
# --> 555     outputs = execute.execute(
#     556         str(self.signature.name),
#     557         num_outputs=self._num_outputs,
#     558         inputs=args,
#     559         attrs=attrs,
#     560         ctx=ctx)
#     561   else:
#     562     outputs = execute.execute_with_cancellation(
#     563         str(self.signature.name),
#     564         num_outputs=self._num_outputs,
#    (...)
#     567         ctx=ctx,
#     568         cancellation_manager=cancellation_manager)
#
# File c:\users\jeetd\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\eager\execute.py:59, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57 try:
#      58   ctx.ensure_initialized()
# ---> 59   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                       inputs, attrs, num_outputs)
#      61 except core._NotOkStatusException as e:
#      62   if name is not None:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_18 (LSTM)               (None, 30, 64)            442112
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 30, 128)           98816
# _________________________________________________________________
# lstm_20 (LSTM)               (None, 64)                49408
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_19 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_20 (Dense)             (None, 6)                 198
# =================================================================
# Total params: 596,774
# Trainable params: 596,774
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 8. Make Predictions

# %%
res = model.predict(X_test)

# %%
actions[np.argmax(res[2])]
# Out:
# 'father'

# %%
actions[np.argmax(y_test[2])]
# Out:
# 'father'

# %% [markdown]
# # 9. Save Weights

# %%
model.save('action.h5')

# %%
del model

# %%
model.load_weights('action.h5')

# %% [markdown]
# # 10. Evaluation using Confusion Matrix and Accuracy

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[6, 2],
#         [0, 1]],
#
#        [[7, 0],
#         [2, 0]],
#
#        [[8, 0],
#         [0, 1]],
#
#        [[8, 0],
#         [0, 1]],
#
#        [[6, 0],
#         [0, 3]],
#
#        [[8, 0],
#         [0, 1]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.7777777777777778

# %% [markdown]
# # 11. Test in Real Time

# %%
from scipy import stats

# %%
colors = [
    (245, 117, 16),  # Orange
    (117, 245, 16),  # Lime green
    (16, 117, 245),  # Blue
    (245, 16, 117),  # Pink
    (117, 16, 245),  # Purple
    (16, 245, 117),  # Light green
    (245, 245, 16),  # Yellow
    (16, 245, 245),  # Cyan
    (245, 16, 245),  # Magenta
    (245, 245, 245)  # White
]
def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()
    for num, prob in enumerate(res):
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85+num*40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
    return output_frame

# %%
# plt.figure(figsize=(18,18))
# plt.imshow(prob_viz(res, actions, image, colors))

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)
# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():

        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            
        #3. Viz logic
            if np.unique(predictions[-10:])[0]==np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    
                    if len(sentence) > 0: 
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5: 
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
            
        cv2.rectangle(image, (0,0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3,30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# i
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mother
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# i
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# i
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# i
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mother
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mother
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mother
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# mother
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# i
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# thanks
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# i
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# hello
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# father
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# iloveyou
